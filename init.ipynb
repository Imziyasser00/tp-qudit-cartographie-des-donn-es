# %%
# %pip install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\yassi\AppData\Local\Programs\Python\Python314\python.exe: No module named pip

# %%
import pandas as pd
for f in ["results", "goalscorers", "shootouts", "former_names"]:
    df = pd.read_csv(f"data/{f}.csv")
    print(f, df.shape)
    print(df.isna().sum(), "\n")
# Out:
# results (49547, 9)
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64
#
# goalscorers (47914, 8)
# date           0
# home_team      0
# away_team      0
# team           0
# scorer        44
# minute       254
# own_goal       0
# penalty        0
# dtype: int64
#
# shootouts (683, 5)
# date               0
# home_team          0
# away_team          0
# winner             0
# first_shooter    423
# dtype: int64
#
# former_names (36, 4)
# current       0
# former        0
# start_date    0
# end_date      0
# dtype: int64

# %%
r = pd.read_csv("data/results.csv")
g = pd.read_csv("data/goalscorers.csv")
s = pd.read_csv("data/shootouts.csv")
key = ["date", "home_team", "away_team"]

print("Doublons dans results :", r.duplicated(subset=key).sum())
print("Buts sans match :", (~g.merge(r[key], on=key, how="left", indicator=True)["_merge"].eq("both")).sum())
print("Tirs au but sans match :", (~s.merge(r[key], on=key, how="left", indicator=True)["_merge"].eq("both")).sum())
# Out:
# Doublons dans results : 1
# Buts sans match : 0
# Tirs au but sans match : 1

# %%
import pandas as pd

for f in ["shootouts", "former_names"]:
    df = pd.read_csv(f"data/{f}.csv")
    print(f, df.shape)
    print(df.isna().sum().to_string(), "\n")
# Out:
# shootouts (683, 5)
# date               0
# home_team          0
# away_team          0
# winner             0
# first_shooter    423
#
# former_names (36, 4)
# current       0
# former        0
# start_date    0
# end_date      0

# %%
print(r[r.duplicated(subset=key, keep=False)])

m = s.merge(r[key], on=key, how="left", indicator=True)
print(m[m["_merge"] == "left_only"])
# Out:
#             date home_team      away_team  home_score  away_score tournament  \
# 9641  1974-02-17    Tahiti  New Caledonia           2           1   Friendly
# 9642  1974-02-17    Tahiti  New Caledonia           1           2   Friendly
#
#          city country  neutral
# 9641  Papeete  Tahiti    False
# 9642  Papeete  Tahiti    False
#            date     home_team      away_team         winner first_shooter  \
# 422  2011-06-29  Saare County  Åland Islands  Åland Islands           NaN
#
#         _merge
# 422  left_only
